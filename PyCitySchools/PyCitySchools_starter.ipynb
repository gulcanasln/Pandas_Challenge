# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("Resources/schools_complete.csv")
student_data_to_load = Path("Resources/students_complete.csv")

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID     student_name gender  year         school_name  \
# 0               0     Paul Bradley      M     9   Huang High School
# 1               1     Victor Smith      M    12   Huang High School
# 2               2  Kevin Rodriguez      M    12   Huang High School
# 3               3    Richard Scott      M    12   Huang High School
# 4               4       Bonnie Ray      F     9   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F    12  Thomas High School
# 39166       39166        Dawn Bell      F    10  Thomas High School
# 39167       39167   Rebecca Tanner      F     9  Thomas High School
# 39168       39168     Desiree Kidd      F    10  Thomas High School
# 39169       39169  Carolyn Jackson      F    11  Thomas High School
#
#        reading_score  maths_score  School ID         type  size   budget
# 0                 96           94          0   Government  2917  1910635
# ...

# %%
#Calculate the total number of schools

school_name_df= school_data_complete['school_name'].unique()
total_school_df= len(school_name_df)
total_school_df
# Out:
# 15

# %%
#calculate the total number of students

total_student_df=school_data_complete['student_name'].count()
total_student_df
# Out:
# 39170

# %%
#calculate the total budget
total_budget_df=school_data['budget'].sum()
total_budget_df
# Out:
# 24649428

# %%
avg_math_score_df=school_data_complete['maths_score'].mean()
avg_math_score_df
# Out:
# 70.33819249425581

# %%
#calculate the average reading score
avg_reading_score_df=school_data_complete['reading_score'].mean()
avg_reading_score_df
# Out:
# 69.98013786060761

# %%
#Calculate the percentage of students with a passing math score(50 or greater)

students_maths_score=school_data_complete.loc[school_data_complete['maths_score']>=50]
number_students_passing_math= students_maths_score['Student ID'].count()
percent_passing_math=(number_students_passing_math/total_student_df)*100
percent_passing_math
# Out:
# 86.07863160582077

# %%
#Calculate the percentage of students with a passing reading score(50 or greater)
students_reading_score=school_data_complete.loc[school_data_complete['reading_score']>=50]
number_students_passing_reading=students_reading_score['Student ID'].count()
percent_passing_reading=(number_students_passing_reading/total_student_df)*100
percent_passing_reading
# Out:
# 84.42685728874139

# %%
#Calculate the percentage of students who passed maths and reading(% overall passing)

overall_passing=school_data_complete[(school_data_complete['maths_score']>=50) & (school_data_complete['reading_score']>=50)
                                     ]['Student ID'].count()/total_student_df*100
overall_passing
# Out:
# 72.80827163645647

# %%
#create a dataframe to hold the above results

summary_df= pd.DataFrame({
    'Total Schools': total_school_df,
    'Total Students': f'{total_student_df:,}',
    'Total Budget': f'$ {total_budget_df:,.2f}',
    'Average Maths Score': f'{avg_math_score_df:,.6f}',
    'Average Reading Score':f'{avg_reading_score_df:,.6f}',
    '% Passing Maths': f'{percent_passing_math:,.6f}',
    '% Passing Reading': f'{percent_passing_reading:,.6f}',
     '% Overall Passing': f'{overall_passing:,.6f}'
}, index=[0])
summary_df
# Out:
#    Total Schools Total Students     Total Budget Average Maths Score  \
# 0             15         39,170  $ 24,649,428.00           70.338192
#
#   Average Reading Score % Passing Maths % Passing Reading % Overall Passing
# 0             69.980138       86.078632         84.426857         72.808272

# %% [markdown]
# * Create an overview table that summarises key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed maths **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#School name 
school_name= school_data_complete.set_index('school_name').groupby(['school_name'])

# %%
#School type
school_type=school_data.set_index('school_name')['type']
#school_type

# %%
#total students
total_student= school_name['Student ID'].count()

# %%
#Total school budget
total_school_budget=school_data.set_index('school_name')['budget']

# %%
#per students budget
budget_per_students=(school_data.set_index('school_name')['budget']/school_data.set_index('school_name')['size'])

# %%
#average math score 
avg_math_score_df=school_name['maths_score'].mean()

# %%
#average reading score 
avg_reading_score_df=school_name['reading_score'].mean()

# %%
#% passing math
pass_math_percent = school_data_complete[school_data_complete['maths_score'] >= 50].groupby('school_name')['Student ID'].count()/total_student*100

# %%
# % passing reading
pass_reading_percent = school_data_complete[school_data_complete['reading_score'] >= 50].groupby('school_name')['Student ID'].count()/total_student*100

# %%
overall_passing_df= school_data_complete[(school_data_complete['maths_score']>=50) & 
                                         (school_data_complete['reading_score']>=50
                                           )].groupby('school_name')['Student ID'].count()/total_student*100

# %%
school_summary=pd.DataFrame({'School Type': school_type,
                            'Total Students': total_student,
                            'Total School Budget': total_school_budget,
                            'Per Student Budget': budget_per_students,
                            'Average Maths Score': avg_math_score_df,
                            'Average Reading Score': avg_reading_score_df,
                            '% Passing Maths': pass_math_percent,
                            '% Passing Reading': pass_reading_percent,
                            '% Overall Passing': overall_passing_df})

school_summary.style.format({'Total Students': '{:}',
                            'Total School Budget': '${:,.2f}',
                            'Per Student Budget': '${:,.2f}',
                            'Average Maths Score': '{:6f}',
                            'Average Reading Score': '{:6f}',
                            '% Passing Maths': '{:6f}',
                            '% Passing Reading': '{:6f}',
                            '% Overall Passing': '{:6f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_87473">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87473_level0_col0" class="col_heading level0 col0" >School Type</th>
#       <th id="T_87473_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_87473_level0_col2" class="col_heading level0 col2" >Total School Budget</th>
#       <th id="T_87473_level0_col3" class="col_heading level0 col3" >Per Student Budget</th>
#       <th id="T_87473_level0_col4" class="col_heading level0 col4" >Average Maths Score</th>
#       <th id="T_87473_level0_col5" class="col_heading level0 col5" >Average Reading Score</th>
#       <th id="T_87473_level0_col6" class="col_heading level0 col6" >% Passing Maths</th>
#       <th id="T_87473_level0_col7" class="col_heading level0 col7" >% Passing Reading</th>
#       <th id="T_87473_level0_col8" class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_performing= school_summary.sort_values('% Overall Passing' , ascending= False)
top_performing.head(5).style.format({'Total Students': '{:}',
                                    'Total School Budget': '${:,.2f}',
                                    'Per Student Budget': '${:,.2f}',
                                    'Average Maths Score': '{:,.6f}',
                                    'Average Reading Score': '{:,.6f}',
                                    '% Passing Maths': '{:,.6f}',
                                    '% Passing Reading': '{:,.6f}',
                                    '% Overall Passing': '{:,.6f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_c2577">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2577_level0_col0" class="col_heading level0 col0" >School Type</th>
#       <th id="T_c2577_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_c2577_level0_col2" class="col_heading level0 col2" >Total School Budget</th>
#       <th id="T_c2577_level0_col3" class="col_heading level0 col3" >Per Student Budget</th>
#       <th id="T_c2577_level0_col4" class="col_heading level0 col4" >Average Maths Score</th>
#       <th id="T_c2577_level0_col5" class="col_heading level0 col5" >Average Reading Score</th>
#       <th id="T_c2577_level0_col6" class="col_heading level0 col6" >% Passing Maths</th>
#       <th id="T_c2577_level0_col7" class="col_heading level0 col7" >% Passing Reading</th>
#       <th id="T_c2577_level0_col8" class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_perform=top_performing.tail()
bottom_performing= bottom_perform.sort_values('% Overall Passing')
bottom_performing.head().style.format({'Total Students': '{:}',
                                    'Total School Budget': '${:,.2f}',
                                    'Per Student Budget': '${:,.2f}',
                                    'Average Maths Score': '{:,.6f}',
                                    'Average Reading Score': '{:,.6f}',
                                    '% Passing Maths': '{:,.6f}',
                                    '% Passing Reading': '{:,.6f}',
                                    '% Overall Passing': '{:,.6f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_99e88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99e88_level0_col0" class="col_heading level0 col0" >School Type</th>
#       <th id="T_99e88_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_99e88_level0_col2" class="col_heading level0 col2" >Total School Budget</th>
#       <th id="T_99e88_level0_col3" class="col_heading level0 col3" >Per Student Budget</th>
#       <th id="T_99e88_level0_col4" class="col_heading level0 col4" >Average Maths Score</th>
#       <th id="T_99e88_level0_col5" class="col_heading level0 col5" >Average Reading Score</th>
#       <th id="T_99e88_level0_col6" class="col_heading level0 col6" >% Passing Maths</th>
#       <th id="T_99e88_level0_col7" class="col_heading level0 col7" >% Passing Reading</th>
#       <th id="T_99e88_level0_col8" class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Maths Scores by Year

# %% [markdown]
# * Create a table that lists the average maths score for students of each year level (9, 10, 11, 12) at each school.
#
#   * Create a pandas series for each year. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
ninth_math = student_data.loc[student_data['year'] ==  9].groupby('school_name')["maths_score"].mean()
tenth_math = student_data.loc[student_data['year'] == 10].groupby('school_name')["maths_score"].mean()
eleventh_math = student_data.loc[student_data['year'] == 11].groupby('school_name')["maths_score"].mean()
twelfth_math = student_data.loc[student_data['year'] == 12].groupby('school_name')["maths_score"].mean()

maths_score = pd.DataFrame({
        "Year 9": ninth_math,
        "Year 10": tenth_math,
        "Year 11": eleventh_math,
        "Year 12": twelfth_math})

maths_score = maths_score[[ "Year 9","Year 10","Year 11","Year 12"]]
maths_score.index.name = "School Name"

#show and format

maths_score.style.format({' 9': '{:.6f}', 
                          " 10": '{:.6f}', 
                          "11": "{:.6f}", 
                          "12": "{:.6f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_4ef57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ef57_level0_col0" class="col_heading level0 col0" >Year 9</th>
#       <th id="T_4ef57_level0_col1" class="col_heading level0 col1" >Year 10</th>
#       <th id="T_4ef57_level0_col2" class="col_heading level0 col2" >Year 11</th>
#       <th id="T_4ef57_level0_col3" class="col_heading level0 col3" >Year 12</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >School Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ef57_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_4ef57_row0_col0" class="data row0 col0" >72.493827</td>
# ...

# %% [markdown]
# ## Reading Score by Year

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
ninth_reading = student_data.loc[student_data['year'] ==  9].groupby('school_name')["reading_score"].mean()
tenth_reading = student_data.loc[student_data['year'] == 10].groupby('school_name')["reading_score"].mean()
eleventh_reading = student_data.loc[student_data['year'] == 11].groupby('school_name')["reading_score"].mean()
twelfth_reading = student_data.loc[student_data['year'] == 12].groupby('school_name')["reading_score"].mean()

reading_score = pd.DataFrame({
        "Year 9": ninth_reading,
        "Year 10": tenth_reading,
        "Year 11": eleventh_reading,
        "Year 12": twelfth_reading})

reading_score = maths_score[[ "Year 9","Year 10","Year 11","Year 12"]]
reading_score.index.name = "School Name"

#show and format

reading_score.style.format({'9': '{:.6f}', 
                          " 10": '{:.6f}', 
                          "11": "{:.6f}", 
                          "12": "{:.6f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec93d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec93d_level0_col0" class="col_heading level0 col0" >Year 9</th>
#       <th id="T_ec93d_level0_col1" class="col_heading level0 col1" >Year 10</th>
#       <th id="T_ec93d_level0_col2" class="col_heading level0 col2" >Year 11</th>
#       <th id="T_ec93d_level0_col3" class="col_heading level0 col3" >Year 12</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >School Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec93d_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_ec93d_row0_col0" class="data row0 col0" >72.493827</td>
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
bins = [0, 585, 630, 645, 680]
group_name = ["<$585", "$585-630", "$630-645", "$645-680"]

school_data_complete['spending_bins'] = pd.cut(school_data_complete['budget']/school_data_complete['size'], bins, labels = group_name)

#group by spending
by_spending = school_data_complete.groupby('spending_bins')


avg_math = by_spending['maths_score'].mean()

avg_read = by_spending['reading_score'].mean()
pass_math = school_data_complete[school_data_complete['maths_score'] >= 50].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()*100
pass_read = school_data_complete[school_data_complete['reading_score'] >= 50].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()*100
overall = school_data_complete[(school_data_complete['reading_score'] >= 50) & (school_data_complete['maths_score'] >= 50)].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()*100
    
# df build            
scores_by_spend = pd.DataFrame({
    "Average Maths Score": avg_math,
    "Average Reading Score": avg_read,
    "% Passing Maths": pass_math,
    "% Passing Reading": pass_read,
    "% Overall Passing": overall
            
})
            
#reorder columns
scores_by_spend = scores_by_spend[[
    "Average Maths Score",
    "Average Reading Score",
    "% Passing Maths",
    "% Passing Reading",
    "% Overall Passing"
]]

scores_by_spend.index.name = "Per Student Budget"


#formating
scores_by_spend.style.format({'Average Maths Score': '{:.2f}', 
                              'Average Reading Score': '{:.2f}', 
                              '% Passing Maths': '{:.2f}', 
                              '% Passing Reading':'{:.2f}', 
                              '% Overall Passing': '{:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5f5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5f5b_level0_col0" class="col_heading level0 col0" >Average Maths Score</th>
#       <th id="T_f5f5b_level0_col1" class="col_heading level0 col1" >Average Reading Score</th>
#       <th id="T_f5f5b_level0_col2" class="col_heading level0 col2" >% Passing Maths</th>
#       <th id="T_f5f5b_level0_col3" class="col_heading level0 col3" >% Passing Reading</th>
#       <th id="T_f5f5b_level0_col4" class="col_heading level0 col4" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Per Student Budget</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
bins = [0, 1000, 2000, 5000]
group_name = ["Small(<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

school_data_complete['size_bins'] = pd.cut(school_data_complete['size'], bins, labels = group_name)

#group by spending
by_size = school_data_complete.groupby('size_bins')


avg_math = by_size['maths_score'].mean()

avg_read = by_size['reading_score'].mean()
pass_math = school_data_complete[school_data_complete['maths_score'] >= 50].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()*100
pass_read = school_data_complete[school_data_complete['reading_score'] >= 50].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()*100
overall = school_data_complete[(school_data_complete['reading_score'] >= 50) & (school_data_complete['maths_score'] >= 50)].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()*100
    
# df build            
scores_by_size = pd.DataFrame({
    "Average Maths Score": avg_math,
    "Average Reading Score": avg_read,
    "% Passing Maths": pass_math,
    "% Passing Reading": pass_read,
    "% Overall Passing": overall
            
})
            
#reorder columns
scores_by_size = scores_by_size[[
    "Average Maths Score",
    "Average Reading Score",
    "% Passing Maths",
    "% Passing Reading",
    "% Overall Passing"
]]

scores_by_size.index.name = "Total Students"
scores_by_size = scores_by_size.reindex(group_name)


#formating
scores_by_size.style.format({'Average Maths Score': '{:.6f}', 
                              'Average Reading Score': '{:.6f}', 
                              '% Passing Maths': '{:.6f}', 
                              '% Passing Reading':'{:.6f}', 
                              '% Overall Passing': '{:.6f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_be944">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be944_level0_col0" class="col_heading level0 col0" >Average Maths Score</th>
#       <th id="T_be944_level0_col1" class="col_heading level0 col1" >Average Reading Score</th>
#       <th id="T_be944_level0_col2" class="col_heading level0 col2" >% Passing Maths</th>
#       <th id="T_be944_level0_col3" class="col_heading level0 col3" >% Passing Reading</th>
#       <th id="T_be944_level0_col4" class="col_heading level0 col4" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Total Students</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
school_type=school_data_complete.groupby('type')


avg_math = school_type['maths_score'].mean()

avg_read = school_type['reading_score'].mean()
pass_math = school_data_complete[school_data_complete['maths_score'] >= 50].groupby('type')['Student ID'].count()/school_type['Student ID'].count()*100
pass_read = school_data_complete[school_data_complete['reading_score'] >= 50].groupby('type')['Student ID'].count()/school_type['Student ID'].count()*100
overall = school_data_complete[(school_data_complete['reading_score'] >= 50) & (school_data_complete['maths_score'] >= 50)].groupby('type')['Student ID'].count()/school_type['Student ID'].count()*100
    
# df build            
scores_by_type = pd.DataFrame({
    "Average Maths Score": avg_math,
    "Average Reading Score": avg_read,
    "% Passing Maths": pass_math,
    "% Passing Reading": pass_read,
    "% Overall Passing": overall
            
})
            
#reorder columns
scores_by_type = scores_by_type[[
    "Average Maths Score",
    "Average Reading Score",
    "% Passing Maths",
    "% Passing Reading",
    "% Overall Passing"
]]

scores_by_type.index.name = "School Type"



#formating
scores_by_type.style.format({'Average Maths Score': '{:.6f}', 
                              'Average Reading Score': '{:.6f}', 
                              '% Passing Maths': '{:.6f}', 
                              '% Passing Reading':'{:.6f}', 
                              '% Overall Passing': '{:.6f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2dd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2dd7_level0_col0" class="col_heading level0 col0" >Average Maths Score</th>
#       <th id="T_e2dd7_level0_col1" class="col_heading level0 col1" >Average Reading Score</th>
#       <th id="T_e2dd7_level0_col2" class="col_heading level0 col2" >% Passing Maths</th>
#       <th id="T_e2dd7_level0_col3" class="col_heading level0 col3" >% Passing Reading</th>
#       <th id="T_e2dd7_level0_col4" class="col_heading level0 col4" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >School Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
